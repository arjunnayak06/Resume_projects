# %% [markdown]
# # Analysis of the sales of a Superstore

# %% [markdown]
# In this project we will see about:
#
#
# Most prefered Segment, Ship mode.
#
# Region with high sales and profits and Region with low sales and losses.
#
# State with high sales, profits and States with low sales and losses.
#
# Number of sales of each Category and Sub-Category.
#
# Identify the weak areas to be worked upon.

# %% [markdown]
# **Importing Required Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Importing the data set**

# %%
data = pd.read_csv('C:/Users/Jakkula Jahnavi/Downloads/SampleSuperstore.csv')

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# Our data contains 9994 rows and 13 columns

# %% [markdown]
# The first ten columns of the dataset

# %%
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# Last ten columns of the dataset

# %%
data.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %% [markdown]
# **Cleaning the data**

# %% [markdown]
# Information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# From above we can see that there are no null points in the data so there is no need to remove any row of the data

# %% [markdown]
# All the columns of the data

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# From above columns we can drop not so useful columns

# %%
new_data= data.drop(['Country', 'Postal Code'], axis=1)

# %%
new_data
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# ...

# %% [markdown]
# Information about the numericals of the data

# %%
new_data.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# **Relation Analysis**

# %% [markdown]
# Checking the corelation between all the numerical data

# %%
correlation = new_data.corr()

sns.heatmap(correlation, cmap='BrBG', annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(new_data)

# %%
new_data = new_data.rename(columns={'Sub-Category':'SubCategory'})

# %%
new_data
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category  SubCategory     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# ...

# %% [markdown]
# Analysis of each category sales

# %%
new_data.groupby('Category').sum()
# Out:
#                        Sales  Quantity  Discount       Profit
# Category
# Furniture        741999.7953      8028    368.89   18451.2728
# Office Supplies  719047.0320     22906    947.80  122490.8008
# Technology       836154.0330      6939    244.40  145454.9481

# %%
sns.countplot(new_data['Category'])
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# **OFFICE SUPPLIES CATEGORY IS THE MOST PREFERRED CATEGORY OF SALES** (i.e., the items sold in more number)

# %% [markdown]
# **FROM TECHNOLOGY CATEGORY THERE ARE MORE NUMBER OF PROFITS**

# %% [markdown]
# Analysis of Sub-Category sales

# %%
SubCategory_sales = pd.DataFrame(new_data.groupby('SubCategory').sum()['Sales'])

# %%
SubCategory_sales
# Out:
#                    Sales
# SubCategory
# Accessories  167380.3180
# Appliances   107532.1610
# Art           27118.7920
# Binders      203412.7330
# Bookcases    114879.9963
# Chairs       328449.1030
# Copiers      149528.0300
# Envelopes     16476.4020
# Fasteners      3024.2800
# Furnishings   91705.1640
# Labels        12486.3120
# Machines     189238.6310
# Paper         78479.2060
# Phones       330007.0540
# Storage      223843.6080
# Supplies      46673.5380
# Tables       206965.5320

# %%
SubCategory_sales = SubCategory_sales.sort_values('Sales', ascending = False)

# %% [markdown]
# Top 10 Sub-Categories of Sales

# %%
SubCategory_sales.head(10)
# Out:
#                    Sales
# SubCategory
# Phones       330007.0540
# Chairs       328449.1030
# Storage      223843.6080
# Tables       206965.5320
# Binders      203412.7330
# Machines     189238.6310
# Accessories  167380.3180
# Copiers      149528.0300
# Bookcases    114879.9963
# Appliances   107532.1610

# %% [markdown]
# Sub-Categories with less number of sales

# %%
SubCategory_sales.tail(5)
# Out:
#                  Sales
# SubCategory
# Supplies     46673.538
# Art          27118.792
# Envelopes    16476.402
# Labels       12486.312
# Fasteners     3024.280

# %% [markdown]
# **The sales of the following 5 Sub-categories is very less, to improve sales they have to add some extra discount on these items as well as promote them widely**

# %%
SubCategory_quantity = pd.DataFrame(new_data.groupby('SubCategory').sum()['Quantity'])

# %%
SubCategory_quantity.sort_values('Quantity', ascending = False)
# Out:
#              Quantity
# SubCategory
# Binders          5974
# Paper            5178
# Furnishings      3563
# Phones           3289
# Storage          3158
# Art              3000
# Accessories      2976
# Chairs           2356
# Appliances       1729
# Labels           1400
# Tables           1241
# Fasteners         914
# Envelopes         906
# Bookcases         868
# Supplies          647
# Machines          440
# Copiers           234

# %% [markdown]
# This is the descending order of number of selling products of Sub-categories

# %%
new_data.SubCategory.value_counts().nlargest(100).plot(kind='bar', figsize=(15,12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Here we can see Blinders are the most selling products**

# %% [markdown]
# **State vs Sales**

# %%
state_data = new_data.groupby('State').sum()['Sales'].reset_index()

# %%
state_data
# Out:
#                    State        Sales
# 0                Alabama   19510.6400
# 1                Arizona   35282.0010
# 2               Arkansas   11678.1300
# 3             California  457687.6315
# 4               Colorado   32108.1180
# 5            Connecticut   13384.3570
# 6               Delaware   27451.0690
# 7   District of Columbia    2865.0200
# 8                Florida   89473.7080
# 9                Georgia   49095.8400
# 10                 Idaho    4382.4860
# 11              Illinois   80166.1010
# 12               Indiana   53555.3600
# 13                  Iowa    4579.7600
# 14                Kansas    2914.3100
# 15              Kentucky   36591.7500
# 16             Louisiana    9217.0300
# 17                 Maine    1270.5300
# 18              Maryland   23705.5230
# 19         Massachusetts   28634.4340
# 20              Michigan   76269.6140
# 21             Minnesota   29863.1500
# 22           Mississippi   10771.3400
# 23              Missouri   22205.1500
# ...

# %%
state_data_figure = state_data.sort_values(['Sales', 'State'])

# %%
state_data_figure
# Out:
#                    State        Sales
# 32          North Dakota     919.9100
# 46         West Virginia    1209.8240
# 17                 Maine    1270.5300
# 39          South Dakota    1315.5600
# 48               Wyoming    1603.1360
# 7   District of Columbia    2865.0200
# 14                Kansas    2914.3100
# 10                 Idaho    4382.4860
# 13                  Iowa    4579.7600
# 29            New Mexico    4783.5220
# 24               Montana    5589.3520
# 27         New Hampshire    7292.5240
# 25              Nebraska    7464.9300
# 38        South Carolina    8481.7100
# 43               Vermont    8929.3700
# 16             Louisiana    9217.0300
# 22           Mississippi   10771.3400
# 42                  Utah   11220.0560
# 2               Arkansas   11678.1300
# 5            Connecticut   13384.3570
# 26                Nevada   16729.1020
# 35                Oregon   17431.1500
# 0                Alabama   19510.6400
# 34              Oklahoma   19683.3900
# ...

# %%
state_data_figure = state_data.sort_values(['Sales', 'State'], ascending= False)

# %%
state_data_figure
# Out:
#                    State        Sales
# 3             California  457687.6315
# 30              New York  310876.2710
# 41                 Texas  170188.0458
# 45            Washington  138641.2700
# 36          Pennsylvania  116511.9140
# 8                Florida   89473.7080
# 11              Illinois   80166.1010
# 33                  Ohio   78258.1360
# 20              Michigan   76269.6140
# 44              Virginia   70636.7200
# 31        North Carolina   55603.1640
# 12               Indiana   53555.3600
# 9                Georgia   49095.8400
# 15              Kentucky   36591.7500
# 28            New Jersey   35764.3120
# 1                Arizona   35282.0010
# 47             Wisconsin   32114.6100
# 4               Colorado   32108.1180
# 40             Tennessee   30661.8730
# 21             Minnesota   29863.1500
# 19         Massachusetts   28634.4340
# 6               Delaware   27451.0690
# 18              Maryland   23705.5230
# 37          Rhode Island   22627.9560
# ...

# %%
plt.figure(figsize=(18,12))
plt.plot(state_data['State'], state_data['Sales'], color='red')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# **From the above graph and data sorted we can see that California has highest number of sales followed by New York and North Dakota is having very less number of sales (0.2% of that of california)**

# %% [markdown]
# **State vs profit**

# %%
state_data = new_data.groupby('State').sum()['Profit'].reset_index()

# %%
state_data
# Out:
#                    State      Profit
# 0                Alabama   5786.8253
# 1                Arizona  -3427.9246
# 2               Arkansas   4008.6871
# 3             California  76381.3871
# 4               Colorado  -6527.8579
# 5            Connecticut   3511.4918
# 6               Delaware   9977.3748
# 7   District of Columbia   1059.5893
# 8                Florida  -3399.3017
# 9                Georgia  16250.0433
# 10                 Idaho    826.7231
# 11              Illinois -12607.8870
# 12               Indiana  18382.9363
# 13                  Iowa   1183.8119
# 14                Kansas    836.4435
# 15              Kentucky  11199.6966
# 16             Louisiana   2196.1023
# 17                 Maine    454.4862
# 18              Maryland   7031.1788
# 19         Massachusetts   6785.5016
# 20              Michigan  24463.1876
# 21             Minnesota  10823.1874
# 22           Mississippi   3172.9762
# 23              Missouri   6436.2105
# ...

# %%
state_data_figure = state_data.sort_values(['Profit', 'State'])

# %%
state_data_figure
# Out:
#                    State      Profit
# 41                 Texas -25729.3563
# 33                  Ohio -16971.3766
# 36          Pennsylvania -15559.9603
# 11              Illinois -12607.8870
# 31        North Carolina  -7490.9122
# 4               Colorado  -6527.8579
# 40             Tennessee  -5341.6936
# 1                Arizona  -3427.9246
# 8                Florida  -3399.3017
# 35                Oregon  -1190.4705
# 48               Wyoming    100.1960
# 46         West Virginia    185.9216
# 32          North Dakota    230.1497
# 39          South Dakota    394.8283
# 17                 Maine    454.4862
# 10                 Idaho    826.7231
# 14                Kansas    836.4435
# 7   District of Columbia   1059.5893
# 29            New Mexico   1157.1161
# 13                  Iowa   1183.8119
# 27         New Hampshire   1706.5028
# 38        South Carolina   1769.0566
# 24               Montana   1833.3285
# 25              Nebraska   2037.0942
# ...

# %%
plt.figure(figsize=(18,12))
plt.plot(state_data['State'], state_data['Profit'], color='blue')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# **From the above figure we can see that California have the highest profits followed by New York followed by West Virigina**

# %% [markdown]
# **Also the states Texas, Ohio, Pennsylvania, Illinois are facing huge losses**

# %% [markdown]
# **Most profitable Category and Sub-Category**

# %%
new_data.groupby(['Category','SubCategory']).sum()
# Out:
#                                    Sales  Quantity  Discount      Profit
# Category        SubCategory
# Furniture       Bookcases    114879.9963       868     48.14  -3472.5560
#                 Chairs       328449.1030      2356    105.00  26590.1663
#                 Furnishings   91705.1640      3563    132.40  13059.1436
#                 Tables       206965.5320      1241     83.35 -17725.4811
# Office Supplies Appliances   107532.1610      1729     77.60  18138.0054
#                 Art           27118.7920      3000     59.60   6527.7870
#                 Binders      203412.7330      5974    567.00  30221.7633
#                 Envelopes     16476.4020       906     20.40   6964.1767
#                 Fasteners      3024.2800       914     17.80    949.5182
#                 Labels        12486.3120      1400     25.00   5546.2540
#                 Paper         78479.2060      5178    102.60  34053.5693
# ...

# %%
cat_subcat_profit = pd.DataFrame(new_data.groupby(['Category','SubCategory']).sum()['Profit'])

# %%
cat_subcat_profit.sort_values(['Category','Profit'], ascending= False)
# Out:
#                                  Profit
# Category        SubCategory
# Technology      Copiers      55617.8249
#                 Phones       44515.7306
#                 Accessories  41936.6357
#                 Machines      3384.7569
# Office Supplies Paper        34053.5693
#                 Binders      30221.7633
#                 Storage      21278.8264
#                 Appliances   18138.0054
#                 Envelopes     6964.1767
#                 Art           6527.7870
#                 Labels        5546.2540
#                 Fasteners      949.5182
#                 Supplies     -1189.0995
# Furniture       Chairs       26590.1663
#                 Furnishings  13059.1436
#                 Bookcases    -3472.5560
#                 Tables      -17725.4811

# %%
cat_subcat_profit.sort_values(['Category','Profit'])
# Out:
#                                  Profit
# Category        SubCategory
# Furniture       Tables      -17725.4811
#                 Bookcases    -3472.5560
#                 Furnishings  13059.1436
#                 Chairs       26590.1663
# Office Supplies Supplies     -1189.0995
#                 Fasteners      949.5182
#                 Labels        5546.2540
#                 Art           6527.7870
#                 Envelopes     6964.1767
#                 Appliances   18138.0054
#                 Storage      21278.8264
#                 Binders      30221.7633
#                 Paper        34053.5693
# Technology      Machines      3384.7569
#                 Accessories  41936.6357
#                 Phones       44515.7306
#                 Copiers      55617.8249

# %% [markdown]
# From the above data frames we can see that under Technology, copiers product is getting very high profits and Machines product is getting less profits comparitively

# %% [markdown]
# Under Office Supplies paper is geting huge profits but where as Supplies is facing losses, so we have to concentrate more on Supplies to overcome the losses

# %% [markdown]
# In Furinture chairs are giving nice profits where as Tables and Bookcases are giving huge loss to the company, have to concentrate more on this area.

# %% [markdown]
# **Region vs Profit**

# %%
region_data = new_data.groupby('Region').sum()['Profit'].reset_index()

# %%
region_data
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
region_data_figure = region_data.sort_values(['Profit', 'Region'])

# %%
region_data_figure
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 2    South   46749.4303
# 1     East   91522.7800
# 3     West  108418.4489

# %%
plt.figure(figsize=(10,6))
plt.plot(state_data['Region'], state_data['Profit'], color='red')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# **West region is getting huge profits followed by East followed by South followed by Central**

# %% [markdown]
# **Profit of Central is just 36.62% of profit of West Region**

# %%
sns.countplot(new_data['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
#  FROM ABOVE PLOT: **MOST PREFFERED SHIPMODE - STANDARD CLASS**

# %%
sns.countplot(new_data['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# FROM ABOVE PLOT: **MOST SALES REGION - WEST**

# %%
sns.countplot(new_data['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %% [markdown]
# FROM ABOVE PLOT: **MOST SALES ARE DONE BY DIRECT CONSUMERS**

# %%
plt.figure(figsize=(18,12))
plt.xticks(rotation='vertical', size=8)
sns.countplot(new_data['State'])
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %% [markdown]
# **FROM ABOVE PLOT: MOST SALES ARE DONE IN CALIFORNIA**

# %% [markdown]
# **STATES TO BE TAKEN EXTRA CARE:** Texas, Ohio, Pennsylvania, Illinois, North Carolina, Colorado, Tennessee, Arizona, Florida, Oregon.
# Store is facing losses in above states
#
# North Dakota despite having the least sales is having profits overall, so if we can implement some method to increase sales that would be good enough

# %% [markdown]
# **PRODUCTS:** Tables, Bookcases and Supplies are incurring losses, that should be taken care of.

# %% [markdown]
# #           THE END
